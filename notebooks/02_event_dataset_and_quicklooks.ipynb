# %% [markdown]
# ## Event Dataset Construction and Quicklook Visualization
#
# This notebook builds event-centered MMS datasets from predefined intervals and generates quicklook spectrogram plots for inspection of candidate ducting structures.

# %%
from duct_detection import (
    export_event_datasets_from_csv,
    batch_plot_event_quicklooks,
)

# %%
# Input interval list
csv_file = "time_interval_formatted_2016_3_1_to_7.csv"

# Output folders
sample_output_dir = "samples"
plot_output_dir = "plotted_events"

# %%
# Build event-centered NetCDF datasets from interval list
export_event_datasets_from_csv(
    csv_file=csv_file,
    output_dir=sample_output_dir,
)

# %%
# Generate Bt-over-EPSD quicklook plots for all exported events
plotted_files = batch_plot_event_quicklooks(
    input_folder=sample_output_dir,
    output_folder=plot_output_dir,
)

# %%
plotted_files
